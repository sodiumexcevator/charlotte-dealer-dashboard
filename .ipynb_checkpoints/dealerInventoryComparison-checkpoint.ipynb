# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mtick
import re

# %% [markdown]
# Things to keep in mind for the data:
# -henddf and stadf don't include VIN
# -henddf doesn't have price for a large portion of the data

# %%
henddf=pd.read_csv("selenium_hend_paginated_scrape.csv")
keffdf=pd.read_csv("selenium_kef_paginated_scrape.csv")
lkndf=pd.read_csv("selenium_LKN_paginated_scrape.csv")
statdf=pd.read_csv("selenium_stateline_paginated_scrape.csv")

# %%
print(henddf.count())
print(keffdf.count())
print(lkndf.count())
print(statdf.count())
# Out:
# Condition/Year/make/model    1637
# Price                         273
# dtype: int64
# Condition/Year    579
# Make-Model        579
# Price             572
# Vin               579
# dtype: int64
# Condition/Year    1572
# Make-Model        1572
# Price             1534
# Vin               1572
# dtype: int64
# Condition/Year    2346
# Make-Model        2346
# Price             2295
# Vin                  0
# dtype: int64

# %%
henddf["Dealer"]="Dealer 1"
keffdf["Dealer"]="Dealer 2"
lkndf["Dealer"]="Dealer 3"
statdf["Dealer"]="Dealer 4"

# %%
henddf.head()
# Out:
#            Condition/Year/make/model    Price    Dealer
# 0         2025 Jeep Compass Latitude  $30,360  Dealer 1
# 1         2025 Jeep Compass Latitude  $30,360  Dealer 1
# 2         2025 Jeep Compass Latitude  $30,360  Dealer 1
# 3  2025 Jeep Grand Cherokee Laredo X      NaN  Dealer 1
# 4  2025 Jeep Grand Cherokee Laredo X      NaN  Dealer 1

# %%
# Split the condition/year/make/model column at the first space
split_cols = henddf["Condition/Year/make/model"].str.split(" ", n=1, expand=True)

# Create the new columns adding new to the conditon/year column since they have no used inventory
henddf["Condition/Year"] = "New " + split_cols[0]
henddf["Make-Model"] = split_cols[1]

#drop the original column
henddf.drop(columns=["Condition/Year/make/model"], inplace=True)

# %%
henddf.head()
# Out:
#      Price    Dealer Condition/Year                    Make-Model
# 0  $30,360  Dealer 1       New 2025         Jeep Compass Latitude
# 1  $30,360  Dealer 1       New 2025         Jeep Compass Latitude
# 2  $30,360  Dealer 1       New 2025         Jeep Compass Latitude
# 3      NaN  Dealer 1       New 2025  Jeep Grand Cherokee Laredo X
# 4      NaN  Dealer 1       New 2025  Jeep Grand Cherokee Laredo X

# %%
comb_df = pd.concat([henddf, keffdf,lkndf, statdf], ignore_index=True)
comb_df.to_csv("comb_dealer_data.csv", index=False)
comb_df.count()
# Out:
# Price             4674
# Dealer            6134
# Condition/Year    6134
# Make-Model        6134
# Vin               2151
# dtype: int64

# %%
irregular_Makes = ["Alfa", "Land", "Rolls"]

# Split condition/year at last space
split_cond_year = comb_df["Condition/Year"].str.rsplit(" ", n=1, expand=True).fillna("")
comb_df["Condition"] = split_cond_year[0]
comb_df["Year"] = split_cond_year[1]

# Handle Make-Model split with special case for irregular makes
def split_make_model(row):
    words = row.split()
    if words and words[0] in irregular_Makes and len(words) > 2:
        make = f"{words[0]} {words[1]}"
        model = " ".join(words[2:])
    else:
        make = words[0] if words else ""
        model = " ".join(words[1:]) if len(words) > 1 else ""
    return pd.Series([make, model])

comb_df[["Make", "Model/Trim"]] = comb_df["Make-Model"].apply(split_make_model)

# Drop the original combined columns
comb_df.drop(columns=["Condition/Year", "Make-Model"], inplace=True)

# %%
np.set_printoptions(threshold=np.inf)
print(comb_df["Make"].unique())
# Out:
# ['Jeep' 'Ram' 'Chrysler' 'Dodge' 'FIAT' 'RAM' 'Ford' 'Hyundai' 'Honda'
#  'Kia' 'Toyota' 'Nissan' 'Audi' 'Lexus' 'Chevrolet' 'BMW' 'GMC' 'Tesla'
#  'Volvo' 'Subaru' 'Genesis' 'INFINITI' 'Alfa Romeo' 'Land Rover' 'Scion'
#  'Mazda' 'Mazda6' 'Lincoln' 'Acura' 'Mercedes-Benz' 'Volkswagen' 'Porsche'
#  'MINI' 'Mitsubishi' 'Buick' 'Coleman' 'Crossroads' 'Cadillac' 'New'
#  'Pre-Owned' 'Certified']

# %%
#fix rows where Make is 'Pre-Owned' or new
mask = comb_df["Make"].isin(["Pre-Owned", "New"])
# Split the Model column at up to 2 spaces
split_model = comb_df.loc[mask, "Model/Trim"].str.split(" ", n=2, expand=True)

# Reassign Make = second word, Model = third word (if available)
comb_df.loc[mask, "Make"] = split_model[1]
comb_df.loc[mask, "Model/Trim"] = split_model[2]

# %%
#fix rows where Make is "Certified"
mask = comb_df["Make"]=='Certified'
# Split the Model column at up to 3 spaces
split_model = comb_df.loc[mask, "Model/Trim"].str.split(" ", n=3, expand=True)

# Reassign Make = second word, Model = third word (if available)
comb_df.loc[mask, "Make"] = split_model[2]
comb_df.loc[mask, "Model/Trim"] = split_model[3]

# %%
np.set_printoptions(threshold=np.inf)
print(comb_df["Make"].unique())
# Out:
# ['Jeep' 'Ram' 'Chrysler' 'Dodge' 'FIAT' 'RAM' 'Ford' 'Hyundai' 'Honda'
#  'Kia' 'Toyota' 'Nissan' 'Audi' 'Lexus' 'Chevrolet' 'BMW' 'GMC' 'Tesla'
#  'Volvo' 'Subaru' 'Genesis' 'INFINITI' 'Alfa Romeo' 'Land Rover' 'Scion'
#  'Mazda' 'Mazda6' 'Lincoln' 'Acura' 'Mercedes-Benz' 'Volkswagen' 'Porsche'
#  'MINI' 'Mitsubishi' 'Buick' 'Coleman' 'Crossroads' 'Cadillac' 'Mazda3'
#  'TOYOTA' 'LEXUS' 'Alfa' 'Land' 'Freightliner' 'Maserati' 'Jaguar'
#  'NISSAN' 'Bentley' 'INEOS' 'JEEP' 'CHRYSLER' 'CHEVROLET']

# %%
# List of makes to drop becuase they are not normal for these dealerships ones a golf cart, the other a camper, and one a tractor
makes_to_drop = ['Coleman', 'Crossroads', 'Freightliner']

# Keep only rows where Make is NOT in the list
comb_df = comb_df[~comb_df["Make"].isin(makes_to_drop)]

# %%
#fix rows where Make is mazda and a number with no space
mask = comb_df["Make"].isin(["Mazda6", "Mazda3"])

# Extract the Make and numeric part from the bad Make column
split_make = comb_df.loc[mask, "Make"].str.extract(r'([A-Za-z]+)(\d+)')

# Fix Make to the text part
comb_df.loc[mask, "Make"] = split_make[0]

# attach the number part to the beginning of the Model
comb_df.loc[mask, "Model/Trim"] = split_make[1] + " " + comb_df.loc[mask, "Model/Trim"]

# %%
# List of irregular makes that need correction
irregular_makes = ["Alfa", "Land", "Rolls"]

# Function to correct 'Make' and 'Model' only when Make is an exact match
def adjust_make_model(row):
    if row['Make'] in irregular_makes:
        model_words = row['Model/Trim'].split()
        if model_words:
            # Append first word of Model to Make
            row['Make'] = f"{row['Make']} {model_words[0]}"
            # Remove the first word from Model
            row['Model/Trim'] = " ".join(model_words[1:])
    return row

# Apply the function across the DataFrame
comb_df = comb_df.apply(adjust_make_model, axis=1)

# %%
# List of known acronyms that should stay fully uppercase
acronyms = ["BMW", "GMC", "RAM", "KIA", "FIAT", "MINI", "BYD", "MG", "HUMMER", "GENESIS"]

def format_make(make):
    make_upper = make.upper()
    if make_upper in acronyms:
        return make_upper
    else:
        return make.capitalize()

# Apply the function
comb_df.loc[:,"Make"] = comb_df["Make"].apply(format_make)

# %%
np.set_printoptions(threshold=np.inf)
print(comb_df["Make"].unique())
# Out:
# ['Jeep' 'RAM' 'Chrysler' 'Dodge' 'FIAT' 'Ford' 'Hyundai' 'Honda' 'KIA'
#  'Toyota' 'Nissan' 'Audi' 'Lexus' 'Chevrolet' 'BMW' 'GMC' 'Tesla' 'Volvo'
#  'Subaru' 'GENESIS' 'Infiniti' 'Alfa romeo' 'Land rover' 'Scion' 'Mazda'
#  'Lincoln' 'Acura' 'Mercedes-benz' 'Volkswagen' 'Porsche' 'MINI'
#  'Mitsubishi' 'Buick' 'Cadillac' 'Maserati' 'Jaguar' 'Bentley' 'Ineos']

# %%
# Define rule-based prefix lists
use_two_word_models = ["Grand", "Model", "Flying", "Range", "Land", "Promaster"]
use_three_word_models = ['AMG®']
drop_first_word_models = ["New", "Romeo", "TRUCKS"]

def custom_model_trim_split(text):
    words = text.split()
    if not words:
        return ("", "")
    
    # Drop the first word if it's in the drop list
    if words[0] in drop_first_word_models:
        words = words[1:]

    # Check 3-word model rules
    if words and words[0] in use_three_word_models and len(words) >= 3:
        model = " ".join(words[:3])
        trim = " ".join(words[3:]) if len(words) > 3 else ""
        return (model, trim)

    # Check 2-word model rules
    if words and words[0] in use_two_word_models and len(words) >= 2:
        model = " ".join(words[:2])
        trim = " ".join(words[2:]) if len(words) > 2 else ""
        return (model, trim)

    # Default: first word is model, rest is trim
    model = words[0]
    trim = " ".join(words[1:]) if len(words) > 1 else ""
    return (model, trim)

# Apply the function
comb_df[["Model", "Trim"]] = comb_df["Model/Trim"].apply(lambda x: pd.Series(custom_model_trim_split(x)))
# Drop the original combined column
comb_df.drop(columns="Model/Trim", inplace=True)

# %%
np.set_printoptions(threshold=np.inf)
print(comb_df["Model"].unique())
# Out:
# ['Compass' 'Grand Cherokee' 'Wrangler' '1500' 'Voyager' 'Durango'
#  'Gladiator' 'Pacifica' 'Promaster Cargo' 'Charger' '2500' 'Wagoneer'
#  '3500' 'Promaster Cutaway' '5500' 'Promaster Delivery' '4500'
#  'Grand Wagoneer' 'ProMaster' 'Hornet' '500e' 'Promaster Window' '4500HD'
#  'Challenger' 'Focus' 'Accent' 'Accord' 'Fusion' 'Elantra' 'Kona' 'Soul'
#  'RAV4' 'Armada' 'Civic' 'Q3' 'Corolla' 'NX' 'Renegade' 'Malibu' 'Camry'
#  '7' 'Cherokee' 'Santa' 'Forte' 'Suburban' 'Sonata' 'Venue' 'CR-V'
#  'Acadia' 'Model 3' 'Tucson' 'ES' 'Terrain' 'XC60' 'Rogue' 'Outback' 'G70'
#  'Palisade' 'Sportage' 'A5' 'Model Y' 'QX80' 'Yukon' 'Maverick' 'GV80'
#  'F-150' 'Mustang' 'GX' 'G80' 'X1' 'Stelvio' 'Silverado' 'GV70'
#  'Transit-250' '4' 'A3' 'Range Rover' 'Carnival' 'Veloster' 'Trax' 'xB'
#  '4Runner' 'Crown' 'CX-9' 'CX-5' '6' 'XV' 'Impreza' 'Sorento' 'X3' 'X5'
#  'Tundra' 'Tacoma' 'Highlander' 'Murano' 'Corsair' 'MDX' 'Ridgeline'
#  'Passport' 'Pilot' 'C' 'Ascent' 'Jetta' 'Taos' 'Tiguan' '3' 'Sierra'
#  'Fiesta' 'Impala' 'Edge' 'Atlas' 'Altima' 'Tahoe' 'Corvette' 'Ranger'
#  'Explorer' 'Expedition' 'Bronco' 'Escape' 'ILX' 'XC90' 'Macan' 'Panamera'
#  'Cooper' 'Z4' '2' '5' 'Q7' 'Q8' 'Q5' 'GLC' 'C-HR' 'Mirage' 'EcoSport'
#  'Envision' 'G90' 'Spark' 'TrailBlazer' 'Trailblazer' 'Encore' 'IS' 'LS'
#  'Forester' 'Crosstrek' 'Cybertruck' 'Telluride' 'Optima' 'K5' 'X7'
#  'Sienna' 'Sequoia' 'Grand Highlander' 'Pathfinder' 'QX60' 'RDX' 'Odyssey'
#  'ZDX' 'Venza' '3.5L' 'Golf' 'Kicks' 'Sentra' 'MKZ' 'SRX' 'Blazer'
#  'Equinox' 'HR-V' 'RX' 'Camaro' 'Town' '300' 'Frontier' 'Escalade' 'LYRIQ'
#  'XT6' 'XT5' 'XT4' 'Savana' 'Canyon' 'Hummer' 'Traverse' 'Express'
#  'Colorado' 'LaCrosse' 'Bolt' 'Transit' 'F-350SD' 'Super' 'F-250SD'
#  'Transit-350' 'Patriot' 'Integra' 'Prius' 'Cruze' 'Stinger' 'M4' 'GLE'
#  '200' 'Journey' 'Grand Caravan' '500L' 'Liberty' 'Enclave' 'Volt' 'TL'
#  'Quest' 'Sonic' 'Versa' 'Flex' 'CT' 'COROLLA' 'Beetle' 'A4' 'ML' 'HS'
#  'Passat' 'ACCORD' 'NV' 'SC' 'iM' 'Equus' 'C-Max' 'Outlander' 'A6' '350Z'
#  'Rio' 'LR4' 'Model S' 'E' 'GS' 'Avalon' 'Giulia' 'CLA' 'QX50' 'Nautilus'
#  'Seltos' 'CX-30' 'Maxima' 'S60' 'GLB' 'Discovery' 'CX-50' 'GLA' 'Titan'
#  'S5' 'SL' 'XC40' 'Navigator' 'RLX' 'Aviator' 'AMG® C 43' 'SQ5' 'Arteon'
#  'TLX' 'EQB' 'Cayenne' 'LEAF' 'CX-90' 'Levante' 'Defender' 'EQS' 'GR' 'S'
#  'A7' 'Grecale' 'Z' 'CX-70' 'XF' 'QX55' 'Ghibli' 'ARIYA' 'S4' '8' 'GLS'
#  'F-PACE' 'i4' 'A8' 'CLE' 'LX' 'AMG® GT 43' 'Taycan' 'Bentayga'
#  'Grenadier' 'Land Cruiser' 'Flying Spur' 'AMG® GT S' 'iX' 'AMG® G 63'
#  'Continental' 'Envista' 'SEQUOIA' 'CAMRY' 'KICKS' 'COMPASS' 'PACIFICA'
#  'MALIBU' 'WRANGLER']

# %%
acronyms = [
    "CR-V", "ES", "IS", "LS", "NX", "RX", "GLC", "C-HR", "MDX", "ILX", "ZDX", "HR-V",
    "MKZ", "SRX", "XT6", "XT5", "XT4", "F-150", "F-250SD", "F-350SD", "GLE", "ML", "TL",
    "TLX", "RLX", "CT", "EQB", "EQS", "G90", "G80", "GV70", "GV80", "G70", "Q3", "Q5",
    "Q7", "Q8", "QX50", "QX55", "QX60", "QX80", "XC40", "XC60", "XC90", "A3", "A4", "A5",
    "A6", "A7", "A8", "S4", "S5", "S60", "SQ5", "CLE", "GLA", "GLB", "GLS", "AMG®", "C",
    "E", "G", "CLA", "GR", "Z4", "Z", "X1", "X3", "X5", "X7", "i", "i4", "iX", "3", "5",
    "7", "8", "4", "EQB", "CX-30", "CX-5", "CX-50", "CX-70", "CX-9",
    "CX-90", "C-Max", "3.5L", "350Z"]
def format_make(model):
    model_upper = model.upper()
    if model_upper in acronyms:
        return model_upper
    else:
        return model.capitalize()

# Apply the function
comb_df.loc[:,"Model"] = comb_df["Model"].apply(format_make)

# %%
np.set_printoptions(threshold=np.inf)
print(comb_df["Model"].unique())
# Out:
# ['Compass' 'Grand cherokee' 'Wrangler' '1500' 'Voyager' 'Durango'
#  'Gladiator' 'Pacifica' 'Promaster cargo' 'Charger' '2500' 'Wagoneer'
#  '3500' 'Promaster cutaway' '5500' 'Promaster delivery' '4500'
#  'Grand wagoneer' 'Promaster' 'Hornet' '500e' 'Promaster window' '4500hd'
#  'Challenger' 'Focus' 'Accent' 'Accord' 'Fusion' 'Elantra' 'Kona' 'Soul'
#  'Rav4' 'Armada' 'Civic' 'Q3' 'Corolla' 'NX' 'Renegade' 'Malibu' 'Camry'
#  '7' 'Cherokee' 'Santa' 'Forte' 'Suburban' 'Sonata' 'Venue' 'CR-V'
#  'Acadia' 'Model 3' 'Tucson' 'ES' 'Terrain' 'XC60' 'Rogue' 'Outback' 'G70'
#  'Palisade' 'Sportage' 'A5' 'Model y' 'QX80' 'Yukon' 'Maverick' 'GV80'
#  'F-150' 'Mustang' 'Gx' 'G80' 'X1' 'Stelvio' 'Silverado' 'GV70'
#  'Transit-250' '4' 'A3' 'Range rover' 'Carnival' 'Veloster' 'Trax' 'Xb'
#  '4runner' 'Crown' 'CX-9' 'CX-5' '6' 'Xv' 'Impreza' 'Sorento' 'X3' 'X5'
#  'Tundra' 'Tacoma' 'Highlander' 'Murano' 'Corsair' 'MDX' 'Ridgeline'
#  'Passport' 'Pilot' 'C' 'Ascent' 'Jetta' 'Taos' 'Tiguan' '3' 'Sierra'
#  'Fiesta' 'Impala' 'Edge' 'Atlas' 'Altima' 'Tahoe' 'Corvette' 'Ranger'
#  'Explorer' 'Expedition' 'Bronco' 'Escape' 'ILX' 'XC90' 'Macan' 'Panamera'
#  'Cooper' 'Z4' '2' '5' 'Q7' 'Q8' 'Q5' 'GLC' 'C-HR' 'Mirage' 'Ecosport'
#  'Envision' 'G90' 'Spark' 'Trailblazer' 'Encore' 'IS' 'LS' 'Forester'
#  'Crosstrek' 'Cybertruck' 'Telluride' 'Optima' 'K5' 'X7' 'Sienna'
#  'Sequoia' 'Grand highlander' 'Pathfinder' 'QX60' 'Rdx' 'Odyssey' 'ZDX'
#  'Venza' '3.5L' 'Golf' 'Kicks' 'Sentra' 'MKZ' 'SRX' 'Blazer' 'Equinox'
#  'HR-V' 'RX' 'Camaro' 'Town' '300' 'Frontier' 'Escalade' 'Lyriq' 'XT6'
#  'XT5' 'XT4' 'Savana' 'Canyon' 'Hummer' 'Traverse' 'Express' 'Colorado'
#  'Lacrosse' 'Bolt' 'Transit' 'F-350SD' 'Super' 'F-250SD' 'Transit-350'
#  'Patriot' 'Integra' 'Prius' 'Cruze' 'Stinger' 'M4' 'GLE' '200' 'Journey'
#  'Grand caravan' '500l' 'Liberty' 'Enclave' 'Volt' 'TL' 'Quest' 'Sonic'
#  'Versa' 'Flex' 'CT' 'Beetle' 'A4' 'ML' 'Hs' 'Passat' 'Nv' 'Sc' 'Im'
#  'Equus' 'C-max' 'Outlander' 'A6' '350Z' 'Rio' 'Lr4' 'Model s' 'E' 'Gs'
#  'Avalon' 'Giulia' 'CLA' 'QX50' 'Nautilus' 'Seltos' 'CX-30' 'Maxima' 'S60'
#  'GLB' 'Discovery' 'CX-50' 'GLA' 'Titan' 'S5' 'Sl' 'XC40' 'Navigator'
#  'RLX' 'Aviator' 'Amg® c 43' 'SQ5' 'Arteon' 'TLX' 'EQB' 'Cayenne' 'Leaf'
#  'CX-90' 'Levante' 'Defender' 'EQS' 'GR' 'S' 'A7' 'Grecale' 'Z' 'CX-70'
#  'Xf' 'QX55' 'Ghibli' 'Ariya' 'S4' '8' 'GLS' 'F-pace' 'I4' 'A8' 'CLE' 'Lx'
#  'Amg® gt 43' 'Taycan' 'Bentayga' 'Grenadier' 'Land cruiser' 'Flying spur'
#  'Amg® gt s' 'Ix' 'Amg® g 63' 'Continental' 'Envista']

# %%
np.set_printoptions(threshold=np.inf)
print(comb_df["Trim"].unique())
# Out:
# ['Latitude' 'Laredo X' 'Sport' 'Tradesman' 'LX' 'GT' 'L Laredo X'
#  'Nighthawk' 'Select' 'Altitude X' 'Sport S' 'Big Horn' 'Limited'
#  'L Altitude X' 'Willys' 'Van Tradesman' 'Mojave' 'L Limited' 'R/T'
#  'Daytona R/T' 'Rebel' 'Sahara' 'Laramie' 'S Limited' 'Hybrid Pinnacle'
#  'Rubicon' '4xe Willys 41' '4xe Sahara' 'S Launch Edition'
#  'Summit Reserve' 'L Summit Reserve' 'Chassis Cab Tradesman'
#  'Van BEV PROMASTER EV SUPER HIGH ROOF 159â\x80\x9d WB EXT' 'Longhorn'
#  'Chassis Cab SLT' 'Series II Obsidian' 'L Series II'
#  'Rubicon 392 Final Edition' 'L LIMITED 4X2'
#  "PROMASTER 1500 TRADESMAN CARGO VAN LOW ROOF 136' W"
#  "PROMASTER 2500 TRADESMAN CARGO VAN HIGH ROOF 159'"
#  "WARLOCK CREW CAB 4X4 5'7 BOX"
#  "Chassis Cab 3500 TRADESMAN CREW CAB CHASSIS 4X4 60' CA"
#  "PROMASTER 1500 TRADESMAN CARGO VAN HIGH ROOF 136'"
#  "BIG HORN CREW CAB 4X4 5'7 BOX" "BIG HORN CREW CAB 4X4 6'4 BOX"
#  'S LIMITED' "PROMASTER 3500 TRADESMAN CARGO VAN HIGH ROOF 159'"
#  'Rubicon X' "TRADESMAN CREW CAB 4X4 6'4 BOX"
#  "TRADESMAN CREW CAB 4X4 8' BOX" 'S LAUNCH EDITION'
#  "LARAMIE CREW CAB 4X4 5'7 BOX" 'Tungsten' "LIMITED CREW CAB 4X4 5'7 BOX"
#  '2-DOOR DAYTONA R/T AWD' "TUNGSTEN CREW CAB 4X4 5'7 BOX" 'RUBICON 4X4'
#  'ALTITUDE X 4X2' '4-DOOR RUBICON' 'GT Plus' 'Classic Tradesman' 'Van SLT'
#  'R/T Plus' 'Warlock' 'Chassis Cab Laramie' 'Power Wagon'
#  'Daytona Scat Pack' 'RHO' 'SRT Hellcat' '' 'L Laredo' 'Laredo'
#  '4xe Sport S' 'Hybrid Select' 'Mojave X' 'Series II Carbide'
#  'Series III Obsidian' 'SLT' '4xe Overland' 'L Series II Carbide'
#  'Van BEV' 'L 4DR 4WD' 'Lone Star' '4xe 4xe' '4xe Rubicon' 'Summit'
#  'L Summit' 'Van BEV 3500 SUPER HI RF 159' 'Touring L' 'Van SLT+'
#  'Van High Roof' 'R/T 20th Anniversary Plus' '4xe High Altitude'
#  '4xe Rubicon X' 'Unlimited Sahara Altitude' 'L' 'L Series III' 'L L 4X4'
#  '4X4' '4xe Willys' '4xe Backcountry' 'SPORT S 4X4' '2-DOOR WILLYS'
#  'WILLYS 4X4' 'LIMITED 4X4' 'RUBICON X 4X4' "REBEL CREW CAB 4X4 5'7 BOX"
#  "BIG HORN CREW CAB 4X4 8' BOX" 'L CARBIDE 4X4'
#  "LARAMIE CREW CAB 4X4 6'4 BOX" "REBEL CREW CAB 4X4 6'4 BOX"
#  "POWER WAGON CREW CAB 4X4 6'4 BOX" "LARAMIE CREW CAB 4X4 8' BOX"
#  '2-DOOR SPORT' '4-DOOR SAHARA' 'Altitude' '2500 High Roof'
#  '3500 Super High Roof' 'Willys 4xe' 'Sport S 4xe' 'Sahara 4xe' '4xe'
#  'Rubicon Mopar Edition 1 of 250' 'Rubicon 4xe' 'Overland 4xe' 'Overland'
#  'Base' 'L Overland' 'Series II' 'R/T Scat Pack'
#  'Willys Fox Factory Black Widow' 'SRT 392' 'Rubicon AEV 370'
#  'Chassis Cab TRADESMAN' 'Rubicon 392' 'AMW Sport 392'
#  'Laramie AEV PROSPECTOR XL' 'SRT Hellcat Redeye DEMON 170'
#  'Rubicon X AMW4x4 Hellcat 707hp' 'Rubicon AMW4X4 840 Demon' 'Titanium'
#  'SE' 'EX-L' 'Value Edition' 'SEL' '75th Anniversary Edition' 'XLE'
#  'Platinum' 'Touring' '2.0T Premium' 'LE' 'N Line' '200t' 'SXT' 'LT'
#  'Hybrid LE' 'Series 750i xDrive' 'Trailhawk' 'Unlimited Sport' 'Fe SEL'
#  'GT-Line' 'X' 'Denali' 'Performance' '350' 'SLE' 'T5 Momentum'
#  'Hybrid Touring' 'SV' 'Onyx Edition XT' 'Standard Range Plus'
#  '3.3T Advanced' 'EX' 'Cruz SEL Premium' 'Hybrid Limited'
#  'Unlimited Sport S' 'XLE Premium' 'X-Line' 'Sportback Premium' 'XRT'
#  'Long Range' 'LUXE' 'L Altitude' 'Cruz Limited' 'Cruz NIGHT'
#  'Calligraphy' 'XL Denali' 'Lariat' '3.5T Advanced +' '3.3T' 'Touring XT'
#  '2.5T' 'XLT' '3.5T' 'GT Premium' '460' 'Unlimited Rubicon' 'Fe Limited'
#  'xDrive28i' 'Recharge Plug-In Hybrid T8 Inscription' 'Unlimited' 'Veloce'
#  '3.3T Sport Advanced' '1500 RST' '2.5T Prestige' 'SEMA Sport'
#  '3.5T Prestige' 'Rubicon HEMI 392' 'SRT Demon' 'Alpine Brigade'
#  'EcoBoost' 'LARAMIE' 'Series III' 'EV Super High Roof' '4xe Sahara 4xe'
#  'Low Roof' 'Big Horn/Lone Star' '4xe Trailhawk 4xe' 'High Roof'
#  '4xe High Altitude 4xe' '4xe Sport S 4xe' '4xe Rubicon X 4xe'
#  '4xe Willys 4xe' 'BaseCamp' '80th Edition' 'Series 435i' '40 Premium'
#  'Premium Plus' 'Velar S' 'SX' 'LXS' 'Fe Limited Ultimate' 'ACTIV' '2RS'
#  '1RS' '300 Base' 'TRD Off-Road Premium' 'SR5' 'SL' 'Grand Touring'
#  '2.5 S Carbon Edition' 'Crosstrek 2.0i Premium' 'WRX STi' 'S' 'sDrive30i'
#  'xDrive40i' 'xDrive30i' 'Reserve' 'Technology' 'RTL-E' 'Special Edition'
#  '300h' '300' '1.4T S' '1.5T SE' '2.0T SE R-Line Black' 'TRD Off-Road'
#  'Series 330i' 'Series 330i xDrive' 'Series 330e iPerformance' '1500 SLT'
#  '1500 LT' '1500 Limited SLE' '1500 LTZ' '2500HD High Country'
#  '2500HD Work Truck' 'LTZ' 'ST Line' 'Hybrid Touring L'
#  'R/T Scat Pack Widebody' 'Cross Sport 2.0T SE w/Technology'
#  '3.6L V6 SEL R-Line' '2.5 S' 'Touring 2.0T' 'RST' 'XL SLE'
#  '1500 High Country' '1500 LTD LT Trail Boss' '1500 Custom' 'Stingray'
#  'Raptor' 'Max Limited' 'Badlands' 'ST' 'EcoBoost Premium'
#  'Laramie Longhorn' 'High Altitude' 'Series I' 'Pursuit' 'Trailhawk 4xe'
#  'WK Limited' 'Freedom Edition' 'Base Camp' 'Uptown' 'Latitude Lux'
#  'Latitude Plus' 'Sahara Altitude' 'Islander' 'JK Unlimited Sport'
#  'JK Unlimited Rubicon' '2.0L' 'TRADESMAN' 'TRX' 'REBEL'
#  'Limited Longhorn' '4xe Base' 'City Base' 'T6 Inscription' 'Inscription'
#  '4' 'S Countryman Base' '250' 'Series 750Li xDrive' 'Series 740i xDrive'
#  'Series 740i' 'Series 228i xDrive' 'Series 530i xDrive'
#  'Series 430i xDrive' 'Series 435i xDrive' 'Series 320i'
#  'Series 530e iPerformance' 'Series M240i' '45 Premium Plus'
#  '3.0T Prestige' '2.0T Prestige' '43 AMG®' 'Velar P250 R-Dynamic S'
#  'Black Edition' 'ES' 'SES' 'Avenir' 'Essence' 'Preferred'
#  '3.5T Sport Advanced' '5.0 Ultimate' 'Calligraphy Night Edition'
#  'SEL Plus' 'Night' '1LT' 'LS' 'RS' 'GX 460 Premium' '350 F SPORT'
#  '460 4DR SDN RWD' 'SR5 Premium' 'Sport SV' '2.5 S Preferred Package'
#  'Wilderness' 'Premium' '2.0i Premium' 'Fe Sport 2.4' 'Fe Sport 2.4 Base'
#  'SX-Prestige X-Line' 'M40i' 'xDrive40e' 'TRD Sport' '1794' 'Hybrid'
#  'Base Plus V6' 'Fe Calligraphy' 'Fe SE' 'Fe XRT' 'A-Spec Package'
#  'Technology Package' 'Elite' 'LCF Base' 'Type S' 'Hybrid XLE Premium'
#  'XSE V6' 'TRD V6' 'Hybrid XSE' 'Hybrid XLE' 'Onyx Edition' '2.0i'
#  'Alltrack TSI SEL' '1.5T S' '2.0T SE' 'SR' '4WD SR' 'Hybrid Reserve'
#  'Luxury' '1500 Denali' '1500 AT4' '1500 Elevation' 'EV LT' 'AT4'
#  '1500 LTD LTZ' '1500 LTD RST' '1500 ZR2' '1500 LT Trail Boss'
#  '1500 Custom Trail Boss' 'Sport Outer Banks' '3500HD High Country'
#  '3500HD LTZ' '2500HD Custom' '2LS' '& Country Limited Platinum'
#  'SRT Hellcat Redeye' 'SRT Hellcat Widebody' '2.0T SE w/Technology'
#  '2.5 SV' '2.5 SR' 'ESV Premium' 'Premium Luxury' '2500 Work Van'
#  '1500 Denali Ultimate' '1500 Pro' '1500 Limited AT4' 'AT4X' 'Elevation'
#  '2500HD SLE' '3500HD Denali' '3500 HD SLT DRW' '2500HD Denali'
#  '2500HD Pro' 'EV Pickup 3X' '1500 LS' 'High Country' 'Premier' 'Z71'
#  'XL SLT' '3500 Work Van' 'Cargo 2500 WT' '1500 LTD High Country'
#  'Trail Boss' 'ZR2' '2500HD LT' '2500 HD High Country' '2500HD LTZ'
#  'Leather Group' 'Grand Sport' 'Z06' 'Stingray Z51' 'EUV Premier' 'SS'
#  'LT1' 'Van T-250 LW RF GVWR' 'Cargo Van T-350 EL HI RF RW' 'XL'
#  'King Ranch' 'Cargo Van T250 LOW RF RWD' 'Duty F-250 SRW XL' 'Active'
#  'Timberline' 'Max Platinum' 'Wildtrak' 'Duty F-350 DRW XL' 'Classic SLT'
#  'Laredo E' 'Unlimited Rubicon 392' 'Unlimited Sahara' 'Unlimited Willys'
#  'Willys Wheeler' 'A-Spec Tech Package' 'Hybrid Hybrid Pinnacle'
#  'Hybrid Hybrid Premium S Appearance Pkg' 'GT Launch Edition' 'Scat Pack'
#  'INSPI(RED)' 'WK Laredo X' 'Upland' 'Limited X'
#  'Unlimited Sahara High Altitude' 'Unlimited High Tide' '4xe Trailhawk'
#  'City Cargo Van Tradesman SLT' 'Four' 'Sedan LX' 'sDrive35i'
#  'Sedan Sport' 'XSE' 'S line Premium Plus' 'Duty F-350 SRW XL' 'ES 350'
#  '4WD SR5' 'AMG® 53' 'i Touring Value' 'ECO w/1XF' 'Touring-L Plus' '300S'
#  'C' 'Crossroad' 'SXT Plus' 'Orange Sport' 'Hemi Orange'
#  'Scat Pack Widebody' 'R/T PLUS' 'SCAT PACK' 'Pop' 'Trekking'
#  'Latitude Altitude' 'Unlimited Willys Wheeler' '80th Anniversary'
#  'Rubicon Recon' 'Willys Sport' 'Unlimited High Altitude'
#  '4xe Rubicon 20th Anniversary' '4xe Summit' 'Unlimited Altitude'
#  'City Cargo Van Tradesman' 'Express' 'Mega Cab Laramie' 'Cargo Van'
#  'Cargo Van High Roof' 'Classic Warlock' 'CXL-1' 'Cpe LX-S' 'CX' '2LT'
#  'w/Black Int' '3.5 SV' 'i Touring' 'Turbo' '2.5i' 'Sdn EX-L' '1500 SLE'
#  'GLS' '350 350' 'GLS PZEV' '200h' 'ECO' 'Fe Sport 2.4L'
#  'Coupe 2.0T Turbo w/Sun/Sound' 'Sedan 1.4T S w/Technology' 'LS Z85'
#  '350 BlueTEC®' '!' '250h' 'Prestige' 'Sedan EX-L' 'R-Line w/Comfort Pkg'
#  'Crosstrek Premium' 'EXL' '1500 SLE1' '430' 'Turbo R-Spec' 'Sdn LX'
#  'Ultimate' 'Sedan Si' 'Hybrid Titanium' 'Leather' 'Sport ES 2.0'
#  'SportWagen SEL' 'Five' 'Duty F-250 King Ranch' '4-Door Touring'
#  'Sport 2.0 ES' 'Sedan LX 1.5T' 'LUX' 'P85D' 'Sport SE'
#  '4-Door Grand Touring' '3.6L V6 SEL' 'Ti Sport' 'FX4' 'LT Cloth'
#  '4WD Work Truck' 'Desert Runner' 'Hybrid XLE Plus' 'LARIAT' '2.0T SEL'
#  'Duty F-250 SRW Lariat' 'PHEV SEL' 'AWD Sport' 'Hatchback XSE' '4WD Z71'
#  '2.5 S Premium Package' 'Standard' '2WD LT' 'ESSENTIAL' '2.5 SL'
#  'Signature' 'Sport Big Bend' 'Cross LE' 'Sport SL' '2.5 S Select Package'
#  'RT' 'SX Turbo' '3.6L V6 SE w/Technology' 'Sport Base' 'Series 530i'
#  '300 BASE' 'w/Premium Package' 'Sedan EX' 'Hatchback Sport Touring'
#  '2WD SR' 'AWD Premium Luxury' 'Sedan 2.5 S' 'Ultimate Dark Theme'
#  'S line Premium' 'Cross L' 'Hybrid SEL' 'Si' '4WD Truck LTD' 'HSE'
#  'Momentum' '3.6L V6 SEL Premium' 'XD SL' 'Technology & A-Spec Packages'
#  'w/Technology Pkg' 'Sedan 2.5 Turbo Premium Plus' 'Sportback Prestige'
#  '2.5 Turbo' '550' 'Connect Van XL' 'X-Pro Prestige' 'R-Design'
#  'w/A-Spec Package' 'Cargo Van Work Van' 'Cross Hybrid SE' 'Max XLT'
#  'Sport Badlands' 'PHEV' 'RX 450hL' '2.5 S Premium Plus Package'
#  'Sport HSE Dynamic' 'TRD Off Road Premium' '63 AMG®' 'SE R-Line Black'
#  'Carbon Edition' 'Ti' '4WD Denali' 'Hybrid Sport' '4WD ZR2'
#  '2.5 Turbo Premium Plus Package' 'SEL Premium R-Line' 'Rock Creek'
#  '1500 LTD LT' 'Hybrid Hybrid XLE' 'Adventure' 'IS 300' 'Black Label'
#  '4WD TRD Off Road' 'Sport HSE Silver Edition' 'Big Bend'
#  'Hybrid Sport Touring' 'PRO-4X' 'Hatchback 2.5 Turbo Premium Plus'
#  'sDrive40i' 'GT2' '4WD TRD Sport' '5.0L Ultimate'
#  '3.6L V6 SEL Premium R-Line' 'w/Advance Package' '2WD SR5'
#  '4WD TRD Off-Road' '2WD Elevation' 'EX X-Line' 'S line Prestige'
#  'SV PLUS' 'PHEV Preferred' '2.0 SR' 'SX X-Pro' 'SENSORY' 'Black Diamond'
#  '3500HD LT' 'Venture' '450+' 'Corolla Circuit Edition' '1SS' '450'
#  'PREMIUM SELECT' 'e Premium Plus' '4WD Limited' 'Duty F-250 SRW LARIAT'
#  '5.0L V8 Supercharged' 'Hybrid Hybrid XSE' 'Series M240i xDrive'
#  'Supra 2.0' 'Outer Banks' 'IS 350 F SPORT Design' 'SX Prestige X-Pro'
#  'Duty F-250 SRW XLT' 'PHEV Premium' 'Sport Core S'
#  '2.0T Peak Edition SEL' 'IS 350 F SPORT' 'A-Spec'
#  'Recharge Plug-In Hybrid Inscription' 'STX' 'PHEV Premium Plus Package'
#  'Hybrid Platinum' 'RDYSE' 'Passenger Wagon XLT' 'Modena' '4WD Platinum'
#  'EVOLVE+' 'Advanced +' 'X-Dynamic HSE' '3.3T Premium'
#  'Series M850i xDrive' 'RDYNAMS' 'R-Dynamic S' '4WD TRD Pro Hybrid'
#  'Type R Base' 'M M' 'LS 500' '3500HD CC Work Truck' '3.5T Sport'
#  'Z51 2LT' 'R-Dynamic SE' 'eDrive40' 'Duty F-250 SRW King Ranch'
#  'BIG HORN' 'L 55' 'Evoque Core S' 'Westminster' 'Duty F-350 SRW LARIAT'
#  'AUTOGRAPH' 'Velar HST' 'Ultimate Bright Theme' 'LX 570'
#  'Duty F-450 DRW Platinum' 'Duty F-450 DRW LARIAT' 'Dark Horse'
#  'Modena Q4' '90 S' 'TRD Pro' 'Duty F-450 DRW Lariat' '110 S' '4S'
#  'xDrive40' 'Velar Dynamic SE' 'L Black Label' 'Duty F-250 SRW Platinum'
#  'W12 Signature' 'Station Wagon Base' 'Duty F-350 DRW XLT' 'ALPINA XB7'
#  'Fieldmaster' 'X-Dynamic SE' 'AMG® 63' 'Sport SE Dynamic' '4WD Sport'
#  '110 X-Dynamic SE' 'GTS' 'Trialmaster' '130 S'
#  'Station Wagon Trialmaster' 'M50' '4 Platinum Edition' 'Dynamic SE'
#  'V8 S' 'Platinum Reserve' 'Carpathian Edition' 'Sport Dynamic SE' 'M60'
#  'GX 550 Luxury+' 'Shelby GT500' 'M Competition' 'V8'
#  'Sport Autobiography' 'Hybrid V8' 'GT V8' 'EWB V8' 'Edition 8'
#  'Edition 8 V8' 'GTC Signature 8 Edition' 'GT Speed Edition 12'
#  '350 Luxury' 'Value' 'Sport Touring' '2.4L Limited'
#  'Black Label Grand Touring' '4WD' 'LATI' 'TOURP' 'U RUBI']

# %%
comb_df.to_csv("LocalChryslerInv.csv", index=False)

# %%
#Code to hunt down iregular values
#list of problematic values
#Problem_children = ["Land"]  # replace with your actual values

# Filter rows where column is in the list
#problem_rows = comb_df[comb_df["Column"].isin(Problem_children)]

# Display the result
#print(problem_rows)
